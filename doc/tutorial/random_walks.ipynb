# %% [markdown]
# # Random Walks in Static Networks
#
# [Run notebook in Google Colab](https://colab.research.google.com/github/pathpy/pathpy/blob/master/doc/tutorial/random_walks.ipynb)
# [Download notebook](https://github.com/pathpy/pathpy/raw/master/doc/tutorial/random_walks.ipynb)
#
# Using the general interafce provided by the abstract class `pathpy.processes.BaseProcess` it is easy to simulate random walks. In the following, we demonstrate this in both a toy example and an empirical network. Let us first import pathoy and create a simple toy network.

# %%
pip install git+git://github.com/pathpy/pathpy.git

# %%
import pathpy as pp
from pprint import pprint
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# Our toy example is a directed network with four nodes and five weighted edges:

# %%
n = pp.Network(directed=True)
n.add_edge('a', 'b', weight=1, uid='a-b')
n.add_edge('b', 'c', weight=1, uid='b-c')
n.add_edge('c', 'a', weight=2, uid='c-a')
n.add_edge('c', 'd', weight=1, uid='c-d')
n.add_edge('d', 'a', weight=1, uid='d-a')
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x6672e263270f489d9e887f661f45be7f"></div>
# <div id="xcc9e06a268f24b57920b3376dc3842ff"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "a-b", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "b-c", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "c-a", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "a", "directed": true, "curved": 0.5}, {"uid": "c-d", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "d", "directed": true, "curved": 0.5}, {"uid": "d-a", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "a", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop

# %% [markdown]
# To simulate a random walk in this network, we first create a `RandomWalk` instance. The constructor will generate a (sparse) transition matrix and use it to initialize the random walk sampling process for a specific network, which is why we need to pass the network instance as the first parameter. Specifying the optional second `weight` attribute will lead to a biased random walk, where the transition probabilities are weighted by the respective numerical property:

# %%
rw = pp.processes.RandomWalk(n, weight='weight')

# %% [markdown]
# We can inspect the sparse transition matrix of the random walk process by using the function `rw.transition_matrix()`:

# %%
print(rw.transition_matrix)
# Out:
#   (0, 1)	1.0
#   (1, 2)	1.0
#   (2, 0)	0.6666666666666666
#   (2, 3)	0.3333333333333333
#   (3, 0)	1.0

# %% [markdown]
# The function `transition_matrix_pd` returns the matrix as a (nicely formatted and properly labelled) pandas DataFrame, which makes it easy to read it:

# %%
print(rw.transition_matrix_pd())
# Out:
#           a    b    c         d
# a  0.000000  1.0  0.0  0.000000
# b  0.000000  0.0  1.0  0.000000
# c  0.666667  0.0  0.0  0.333333
# d  1.000000  0.0  0.0  0.000000

# %% [markdown]
# To compute the stationary visitation probabilites of the random walk, we can call:

# %%
rw.stationary_state()
# Out:
# array([0.3, 0.3, 0.3, 0.1])

# %% [markdown]
# Following the general design of the class `BaseProcess`, we can use the iterator function `simulation_run` to iterate through the steps of a random walk with a given length. If we specify `seed`, the walk will start from the given node uid.
#
# In each step, the iterator will yield the current time, as well as a tuple containing those nodes whose state has changed. In the random walk process, this is the currently visited node (the first entry in the tuple) and the previous node, that is now not visited anymore (the second entry in the tuple).
#
# In each step, we can use properties and methods to access the current state of the random walk, e.g. we can output the current node visitation frequencies as well as the total variation distance to the stationary visitation probabilities. Note that the first iteration yields the status after the first transition, i.e. in the following example, the random walk is initialized in node `a` at time 0.

# %%
for time, updated_nodes in rw.simulation_run(steps=10, seed='a'):
    print('time = {0}, current node = {1}'.format(time, updated_nodes[0]))
    pprint(rw.visitation_frequencies)
    print(rw.total_variation_distance)
# Out:
# time = 1, current node = b
# array([0.5, 0.5, 0. , 0. ])
# 0.39999999999999997
# time = 2, current node = c
# array([0.33333333, 0.33333333, 0.33333333, 0.        ])
# 0.10000000000000017
# time = 3, current node = a
# array([0.5 , 0.25, 0.25, 0.  ])
# 0.19999999999999996
# time = 4, current node = b
# array([0.4, 0.4, 0.2, 0. ])
# 0.19999999999999998
# time = 5, current node = c
# array([0.33333333, 0.33333333, 0.33333333, 0.        ])
# 0.10000000000000017
# time = 6, current node = d
# array([0.28571429, 0.28571429, 0.28571429, 0.14285714])
# 0.042857142857142684
# time = 7, current node = a
# array([0.375, 0.25 , 0.25 , 0.125])
# 0.09999999999999976
# time = 8, current node = b
# array([0.33333333, 0.33333333, 0.22222222, 0.11111111])
# 0.07777777777777753
# time = 9, current node = c
# array([0.3, 0.3, 0.3, 0.1])
# 2.2898349882893854e-16
# time = 10, current node = d
# array([0.27272727, 0.27272727, 0.27272727, 0.18181818])
# 0.08181818181818165

# %% [markdown]
# We can use the function `run_experiment` to generate data on multiple runs of a random walker starting in different nodes. This method will return a data frame, that contains all node changes that ocurred during the simulations. To generate two runs of a random walk with 10 steps each, starting from node `a` and node `b` we thus call:

# %%
data = rw.run_experiment(steps=10, runs=['a', 'b'])
print(data)
# Out:
#     run_id seed  time node  state
# 0        0    a     0    d  False
# 1        0    a     0    c  False
# 2        0    a     0    a   True
# 3        0    a     0    b  False
# 4        0    a     1    b   True
# 5        0    a     1    a  False
# 6        0    a     2    c   True
# 7        0    a     2    b  False
# 8        0    a     3    d   True
# 9        0    a     3    c  False
# 10       0    a     4    a   True
# 11       0    a     4    d  False
# 12       0    a     5    b   True
# 13       0    a     5    a  False
# 14       0    a     6    c   True
# 15       0    a     6    b  False
# 16       0    a     7    a   True
# 17       0    a     7    c  False
# 18       0    a     8    b   True
# 19       0    a     8    a  False
# 20       0    a     9    c   True
# 21       0    a     9    b  False
# 22       0    a    10    d   True
# 23       0    a    10    c  False
# 24       1    b     0    d  False
# 25       1    b     0    c  False
# 26       1    b     0    a  False
# 27       1    b     0    b   True
# 28       1    b     1    c   True
# 29       1    b     1    b  False
# 30       1    b     2    a   True
# 31       1    b     2    c  False
# 32       1    b     3    b   True
# 33       1    b     3    a  False
# 34       1    b     4    c   True
# 35       1    b     4    b  False
# 36       1    b     5    a   True
# 37       1    b     5    c  False
# 38       1    b     6    b   True
# 39       1    b     6    a  False
# 40       1    b     7    c   True
# 41       1    b     7    b  False
# 42       1    b     8    d   True
# 43       1    b     8    c  False
# 44       1    b     9    a   True
# 45       1    b     9    d  False
# 46       1    b    10    b   True
# 47       1    b    10    a  False

# %% [markdown]
# While this data frame can be easily exported or visualised, we often want to retrieve `Path` objects that capture the trajectories of random walks. This allows, for instance, to fit higher-order models based on observed random walks. We can use the `get_path` function to retrieve a single path from the data recorded during an experiment. We can specify the `run_id` of the path that shall be extracted, a zero-based counter that is automatically generated during the experiment:

# %%
p = rw.get_path(data, run_id=1)
print(p)
# Out:
# Uid:		0x247ff9232b0
# Type:		Path
# Directed:	True
# Nodes:		{'b': Empty b, 'c': Empty c, 'a': Empty a, 'd': Empty d}
# Relations:	('b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b')

# %% [markdown]
# If we omit the `run_id`, the first run (with ID 0) will be returned as a path:

# %%
p = rw.get_path(data)
print(p)
# Out:
# Uid:		0x247ff923c88
# Type:		Path
# Directed:	True
# Nodes:		{'a': Empty a, 'b': Empty b, 'c': Empty c, 'd': Empty d}
# Relations:	('a', 'b', 'c', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'd')

# %% [markdown]
# We can use the `get_paths` function of the `RandomWalk` class to generate a `PathCollection` containing all paths captured by a list of run_ids (or all runs in a data frame if we omit the `run_ids` argument):

# %%
pc = rw.get_paths(data, run_ids=[0, 1])
print(pc)
# Out:
# {Path ('b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b'), Path ('a', 'b', 'c', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'd')}

# %% [markdown]
# We can use the data frame returned by `run_experiment` to generate an interactive visualisation of the random walk process. We just have to pass the data frame to the `plot` function of the random walk instance. The result is a temporal network visualization, where we can use a slider bar to move forward and backward through time.
#
# The `plot` function accepts a `run_id` argument that defines which of the recorded random walks in `data` shall be visualised. If we omit this parameter, the first random walk will be visualised.

# %%
rw.plot(data, run_id=0)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xee16a4f2f73245349c8e05c8fe1d83bb"></div>
# <div id="x3096b641ca774b13b55296e9c534baf0"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": true, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": "1970-01-01T00:00:00", "end": "1970-01-01T00:16:40", "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "d", "size": 15.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "a", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "changes": [], "tedges": [{"uid": "0x247ff942668", "startTime": 0, "endTime": 19, "active": true}, {"uid": "0x247ff942780", "startTime": 0, "endTime": 19, "active": true}, {"uid": "0x247ff9427b8", "startTime": 0, "endTime": 19, "active": true}, {"uid": "0x247ff9427f0", "startTime": 0, "endTime": 19, "active": true}, {"uid": "0x247ff942908", "startTime": 0, "endTime": 19, "active": true}], "tnodes": [{"uid": "a", "startTime": 0, "endTime": 0, "active": true, "color": "red"}, {"uid": "a", "startTime": 0, "endTime": 0, "active": false, "color": null}, {"uid": "a", "startTime": 0, "endTime": 2, "active": true}, {"uid": "a", "startTime": 2, "endTime": 2, "active": false}, {"uid": "a", "startTime": 2, "endTime": 2, "active": true, "color": "blue"}, {"uid": "a", "startTime": 2, "endTime": 2, "active": false, "color": null}, {"uid": "a", "startTime": 2, "endTime": 8, "active": true}, {"uid": "a", "startTime": 8, "endTime": 8, "active": false}, {"uid": "a", "startTime": 8, "endTime": 8, "active": true, "color": "red"}, {"uid": "a", "startTime": 8, "endTime": 8, "active": false, "color": null}, {"uid": "a", "startTime": 8, "endTime": 10, "active": true}, {"uid": "a", "startTime": 10, "endTime": 10, "active": false}, {"uid": "a", "startTime": 10, "endTime": 10, "active": true, "color": "blue"}, {"uid": "a", "startTime": 10, "endTime": 10, "active": false, "color": null}, {"uid": "a", "startTime": 10, "endTime": 13, "active": true}, {"uid": "a", "startTime": 13, "endTime": 13, "active": false}, {"uid": "a", "startTime": 13, "endTime": 13, "active": true, "color": "red"}, {"uid": "a", "startTime": 13, "endTime": 13, "active": false, "color": null}, {"uid": "a", "startTime": 13, "endTime": 15, "active": true}, {"uid": "a", "startTime": 15, "endTime": 15, "active": false}, {"uid": "a", "startTime": 15, "endTime": 15, "active": true, "color": "blue"}, {"uid": "a", "startTime": 15, "endTime": 15, "active": false, "color": null}, {"uid": "a", "startTime": 15, "endTime": 19, "active": true}, {"uid": "a", "startTime": 19, "endTime": 19, "active": false}, {"uid": "a", "startTime": 0, "endTime": 0, "active": true, "color": "red"}, {"uid": "a", "startTime": 0, "endTime": 0, "active": false, "color": null}, {"uid": "a", "startTime": 0, "endTime": 2, "active": true}, {"uid": "a", "startTime": 2, "endTime": 2, "active": false}, {"uid": "a", "startTime": 2, "endT

# %% [markdown]
# Apart from specifying a list of start nodes, we can also give a number of runs that shall be simulated. In this case, the seed nodes of the individual simulation runs are chosen uniformly at random.

# %%
pc = rw.get_paths(rw.run_experiment(steps=10, runs=20))
print(pc)
# Out:
# {Path ('b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c'), Path ('c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd'), Path ('c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b', 'c'), Path ('b', 'c', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b'), Path ('a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a'), Path ('b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b'), Path ('c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a'), Path ('c', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b'), Path ('d', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'a', 'b', 'c'), Path ('a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'a'), Path ('d', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'd', 'a', 'b'), Path ('d', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a'), Path ('d', 'a', 'b', 'c', 'a', 'b', 'c', 'd', 'a', 'b', 'c')}

# %% [markdown]
# If `runs` is a list of `Node` objects, a single random walk will be generated for each start node. To generate exactly one random walk starting in each node of the network, we can simply pass the node uids of a network:

# %%
pc = rw.get_paths(rw.run_experiment(steps=10, runs=n.nodes.uids))
for p in pc:
    print(p)
# Out:
# Uid:		0x247ff98b400
# Type:		Path
# Directed:	True
# Nodes:		{'d': Empty d, 'a': Empty a, 'b': Empty b, 'c': Empty c}
# Relations:	('d', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'a', 'b', 'c')
#
# Uid:		0x247ff98b4a8
# Type:		Path
# Directed:	True
# Nodes:		{'c': Empty c, 'd': Empty d, 'a': Empty a, 'b': Empty b}
# Relations:	('c', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c')
#
# Uid:		0x247ff98b390
# Type:		Path
# Directed:	True
# Nodes:		{'a': Empty a, 'b': Empty b, 'c': Empty c, 'd': Empty d}
# Relations:	('a', 'b', 'c', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a')
#
# Uid:		0x247ff98b550
# Type:		Path
# Directed:	True
# Nodes:		{'b': Empty b, 'c': Empty c, 'a': Empty a, 'd': Empty d}
# Relations:	('b', 'c', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'd', 'a')

# %% [markdown]
# We close this tutorial with a random walk simulation in an empirical network.

# %%
n = pp.io.graphtool.read_netzschleuder_network('game_thrones')
rw = pp.processes.RandomWalk(n, weight='weight')
rw.plot(rw.run_experiment(steps=100))
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x8990e1d150f443be8446af848aef1e01"></div>
# <div id="xae6ca0fd6abc4cbc9a43fecb41cfccb4"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": true, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": "1970-01-01T00:00:00", "end": "1970-01-01T02:46:40", "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "84", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "66", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "70", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "6", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "65", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "104", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "11", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "9", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "77", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "103", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "83", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "55", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "54", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "79", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "59", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "2", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "67", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "101", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "58", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "82", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "76", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "32", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "7", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "50", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "80", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "49", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "93", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "102", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "86", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "52", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "0", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "98", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "27", "size": 15.0, "color": "blue", "opa
