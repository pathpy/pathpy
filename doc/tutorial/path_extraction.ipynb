# %% [markdown]
# # Extracting paths from temporal networks
#
# [Run notebook in Google Colab](https://colab.research.google.com/github/pathpy/pathpy/blob/master/doc/tutorial/path_extraction.ipynb)
# [Download notebook](https://github.com/pathpy/pathpy/raw/master/doc/tutorial/path_extraction.ipynb)
#
# This short tutorial demonstrates (and explains) how to calculate time-respecting path frequencies in a temporal network.

# %% [markdown]
# pip install git+git://github.com/pathpy/pathpy.git

# %%
import pathpy as pp
import io
import numpy as np
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# We first generate a maximally simple temporal network with three (instantaneous) time-stamped edges:

# %%
tn = pp.TemporalNetwork()
tn.add_edge('a', 'b', timestamp=1)
tn.add_edge('b', 'c', timestamp=2)
tn.add_edge('b', 'd', timestamp=5)
tn.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xa22cf12faca745db8625d1f6998ad522"></div>
# <div id="xad1991eb88f24a6596dd7c0156d453cc"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": true, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": "1970-01-01T00:00:01", "end": "1970-01-01T00:00:06", "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "changes": [], "tedges": [{"uid": "0x2a1fe069cc0", "startTime": 0, "endTime": 4, "active": true}, {"uid": "0x2a1fe069be0", "startTime": 4, "endTime": 8, "active": true}, {"uid": "0x2a19ec9fe10", "startTime": 15, "endTime": 19, "active": true}], "tnodes": [], "links": [{"uid": "0x2a1fe069cc0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe069be0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x2a19ec9fe10", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "d", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {

# %% [markdown]
# As a first step, we can turn this temporal network into a time-unfolded directed acyclic graph. For this, we have to specify the maximum time difference delta between any two time-stamped edges that shall constitute a time-respecting or causal path. In addition to occuring within the maximum time difference, time-stamped edges also have to occur in the correct temporal ordering.
#
# In the resulting time-unfolded directed acyclic graph, each time-unfolded node `v_t` represents a node `v` at a given time stamp `t`. Each edge (`v_t`, `w_{t'}`) between such time-unfolded nodes represents a possible causal influence (i.e. a time-respecting of causal path) by which node `v` at time `t` can influence node `w` at `t'>t`.
#
# By definition, each time-stamped edge (`v`, `w`, t) is a causal path of length one by which node `v` at time `t` can influence node `w` at the next timestamp `t+1` (i.e. we assume that it takes one unit of time for influence to traverse an edge). For a maximum time difference of one between two edges, the only causal path of length two connects node `a` (at time 1) via node `b` (at time 2) to node `c` at time 3. We can see this in the resulting time-unfolded directed acyclic graph:

# %%
dag = pp.DirectedAcyclicGraph.from_temporal_network(tn, delta=1)
dag.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x781d0190127a48c59b8a686049b76583"></div>
# <div id="xf08a62f5857e435ebe79a1d732fb0cf3"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a_1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x2a1fe093438", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_2", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe093860", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe093c50", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_6", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){

# %% [markdown]
# If we increase the maximum time difference to `delta=2` three additional time-respecting paths of length one emerges (one from `b` at time 5 to `d` at time 7,  one from `a` at time 1 to `b` at time 3, and one from node `b` at time 2 to node `c` at time 4). This further implies one additional time-respecting path of length two, which is represented in the DAG below:

# %%
dag = pp.DirectedAcyclicGraph.from_temporal_network(tn, delta=2)
dag.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x7b103d49bcbf437aa8c3d366b60e60a8"></div>
# <div id="x7c4a7004467044ca83f56fb139d35517"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a_1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_7", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x2a1fe093dd8", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_2", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a10f0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1208", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a12e8", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_4", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1400", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_6", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a14e0", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_7", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX

# %% [markdown]
# If we set the delta to a maximum value of `infinity`, only the time-ordering of time-stamped edges is considered, i.e. any time gap between edges is allowed. In the example above, this implies that the state of node `a` at time `t=1` can influence any other node at any later time. In the directed acyclic graph this is represented as:

# %%
dag = pp.DirectedAcyclicGraph.from_temporal_network(tn, delta=np.inf)
dag.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xf19218d5e5b04218a62b7c88423feed5"></div>
# <div id="x89e513bf2cd54b42926c8280b5a33714"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a_1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x2a1fe0932b0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_2", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a15c0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a16a0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_4", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1780", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_5", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1860", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_6", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1940", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1a90", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_4", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1b70", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_5", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1c50", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_6", "directed": true, "curved": 0.5}, {"uid": "0x2a1fdfe8ba8", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_6", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    //

# %% [markdown]
# Thanks to its acyclicity, a directed acyclic graph can be used to calculate a finite set of all paths from any root node (the potential start node/time of a causal path in a temporal network) to any leaf node (the potential end node/time of a causal path) in the DAG. We can use the `roots` and `leafs` properties of the `DirectedAcyclicGraph` class to return those:

# %%
print([v.uid for v in dag.roots])
print([v.uid for v in dag.leafs])
# Out:
# ['a_1']
# ['c_6', 'b_6', 'c_4', 'b_4', 'd_6', 'c_5', 'c_3', 'b_3']

# %% [markdown]
# We can calculate all possible paths from a given root node to any leaf node i nthe DAG as follows:

# %%
paths = dag.routes_from('a_1')
paths
# Out:
# Counter({('a_1', 'b_6'): 1,
#          ('a_1', 'b_4'): 1,
#          ('a_1', 'b_3'): 1,
#          ('a_1', 'b_2', 'c_6'): 1,
#          ('a_1', 'b_2', 'c_4'): 1,
#          ('a_1', 'b_2', 'c_5'): 1,
#          ('a_1', 'b_2', 'c_3'): 1,
#          ('a_1', 'b_5', 'd_6'): 1})

# %% [markdown]
# To calculate the statistics of all paths from all roots, we can call the following function. In the example above, this is identical to the paths from the root `a_1` since there is a single root node only in this DAG.

# %%
paths = pp.algorithms.path_extraction.all_paths_from_dag(dag)
paths
# Out:
# Counter({('a_1', 'b_6'): 1,
#          ('a_1', 'b_4'): 1,
#          ('a_1', 'b_3'): 1,
#          ('a_1', 'b_2', 'c_6'): 1,
#          ('a_1', 'b_2', 'c_4'): 1,
#          ('a_1', 'b_2', 'c_5'): 1,
#          ('a_1', 'b_2', 'c_3'): 1,
#          ('a_1', 'b_5', 'd_6'): 1})

# %% [markdown]
# The problem with this is that we are actually not interested in paths in the time-unfolded directed acyclic graph, but in causal, i.e. time-respecting paths in the original network. In our example, different nodes in the directed acyclic graph actually correspond to the same node in the network at different times. For instance, nodes `b_4` and `b_6` represent the same node `b` at time `4` and `6`.
#
# For the calculation of paths in the original network, we must incorporate this information. pathpy supports this via a custom node mapping, that we can pass to the path calculation. Moreover, each node in the directed acyclic graph generated by the `from_temporal_network` function has a node attribute `original` that contains the ID of the original node in the temporal network. To map DAG nodes to such nodes we can thus write:

# %%
paths = pp.algorithms.path_extraction.all_paths_from_dag(dag, node_mapping={ v.uid: v['original'].uid for v in dag.nodes })
paths
# Out:
# Counter({('a', 'b'): 1, ('a', 'b', 'c'): 1, ('a', 'b', 'd'): 1})

# %% [markdown]
# We have now mapped four different paths `a->b->c` to a single causal path, because the different paths in the original DAG all represent the same path from a single root node to the same (mapped) leaf node. The only difference is that transitions between nodes happen at different times.
#
# It might appear that this is all we need to calculate statistics of causal paths in a temporal network. However, the situation is more complicated if we additionally consider which of the shorter paths are already contained in the longer paths. Let us reconsider the DAG generated above:

# %%
dag.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xd94a62ae69e9405490d694c97a1eabf8"></div>
# <div id="x02373aad0e9140f4a7630a76ccb46503"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a_1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x2a1fe0932b0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_2", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a15c0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a16a0", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_4", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1780", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_5", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1860", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_6", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1940", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1a90", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_4", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1b70", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_5", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0a1c50", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_6", "directed": true, "curved": 0.5}, {"uid": "0x2a1fdfe8ba8", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_6", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    //

# %% [markdown]
# In the original temporal network, there are actually only three temporal edges `(a,b), (b,c)` and `(c,d)` occurring in sequence. This leads to two different longest causal paths of length two, which contain the three shorter causal paths of length one (i.e. the edges).
#
# The idea to focus on longest causal paths only is the basis for the calculation of poath statistics using the following function:

# %%
paths = pp.algorithms.path_extraction.all_paths_from_temporal_network(tn, delta=np.inf)
paths
# Out:
# Counter({('a', 'b', 'c'): 1, ('a', 'b', 'd'): 1})

# %% [markdown]
# In the example above, we only have a single root node, which is why the path statistics for the whole DAG is identical to the statistics returned for the paths originating in the single root note.
#
# In our temporal network with delta=2 we actually have two different roots, hence we have to consider causal paths starting in different nodes:

# %%
dag = pp.DirectedAcyclicGraph.from_temporal_network(tn, delta=2)
dag.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x36a4114ddfb74a639da92804eb842292"></div>
# <div id="x387ca281d13a43a6a025d82bc977c6f2"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a_1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c_4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b_5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d_7", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x2a1fe0c1c18", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_2", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0c1eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a_1", "target": "b_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0c1c50", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_3", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0d4278", "size": 2.0, "color": "black", "opacity": 1, "source": "b_2", "target": "c_4", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0d46a0", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_6", "directed": true, "curved": 0.5}, {"uid": "0x2a1fe0d4400", "size": 2.0, "color": "black", "opacity": 1, "source": "b_5", "target": "d_7", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX

# %%
paths = dag.routes_from('a_1')
paths
# Out:
# Counter({('a_1', 'b_3'): 1,
#          ('a_1', 'b_2', 'c_3'): 1,
#          ('a_1', 'b_2', 'c_4'): 1})

# %%
paths = dag.routes_from('b_5')
paths
# Out:
# Counter({('b_5', 'd_7'): 1, ('b_5', 'd_6'): 1})

# %%
paths = pp.algorithms.path_extraction.all_paths_from_dag(dag)
paths
# Out:
# Counter({('b_5', 'd_7'): 1,
#          ('b_5', 'd_6'): 1,
#          ('a_1', 'b_3'): 1,
#          ('a_1', 'b_2', 'c_3'): 1,
#          ('a_1', 'b_2', 'c_4'): 1})

# %%
paths = pp.algorithms.path_extraction.all_paths_from_temporal_network(tn, delta=2)
paths
# Out:
# Counter({('a', 'b', 'c'): 1, ('b', 'd'): 1})

# %%
tn = pp.TemporalNetwork()
tn.add_edge('a', 'b', timestamp=1)
tn.add_edge('b', 'c', timestamp=2)
tn.add_edge('b', 'd', timestamp=5)
tn.add_edge('a', 'b', timestamp=12)
tn.add_edge('b', 'c', timestamp=13)
paths = pp.algorithms.path_extraction.all_paths_from_temporal_network(tn, delta=2)
paths
# Out:
# Counter({('a', 'b', 'c'): 2, ('b', 'd'): 1})

# %%
pp.io.infomap.to_state_file(paths, 'test.state', weight=True)

# %%
with io.open('test.state', 'r') as f:
    print(f.read())
# Out:
# *Vertices 4
# 1 "d"
# 2 "a"
# 3 "c"
# 4 "b"
# *States
# 1 2 "{eps}_a"
# 2 4 "{a}_b"
# 3 3 "{a-b}_c"
# 4 4 "{eps}_b"
# 5 1 "{b}_d"
# *Links
# 1 2 2
# 2 3 2
# 4 5 1

# %%
n = pp.io.konect.read_konect_name('sociopatterns-hypertext')
print(n)
# Out:
# Uid:			0x2a1800677b8
# Type:			TemporalNetwork
# Directed:		False
# Multi-Edges:		True
# Number of unique nodes:	113
# Number of unique edges:	2196
# Number of temp nodes:	113
# Number of temp edges:	20818
# Observation periode:	1246255220 - 1246467561.0
#
# Network attributes
# ------------------
# category:	HumanContact
# code:	HY
# name:	Hypertext 2009
# description:	Visitorâ€“visitor face-to-face contacts
# extr:	sociopatterns
# url:	http://www.sociopatterns.org/
# long-description:	This is the network of face-to-face contacts of the attendees of the ACM Hypertext 2009 conference. The ACM Conference on Hypertext and Hypermedia 2009 (HT 2009, http://www.ht2009.org/) was held in Turin, Italy over three days from June 29 to July 1, 2009. In the network, a node represents a conference visitor, and an edge represents a face-to-face contact that was active for at least 20 seconds. Multiple edges denote multiple contacts. Each edge is annotated with the time at which the contact took place.
# entity-names:	visitor
# relationship-names:	contact
# cite:	konect:sociopatterns
# time:	2009-06-29/2009-07-01
# timeiso:	2009-06-29/2009-07-01

# %%
validation, train = pp.algorithms.evaluation.train_test_split(n, train_size = 0.8, split = "time")

# %%
train_paths = pp.algorithms.path_extraction.all_paths_from_temporal_network(train, delta=1)
train_paths
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8c70146f01d6> in <module>
# ----> 1 train_paths = pp.algorithms.path_extraction.all_paths_from_temporal_network(train, delta=1)
#       2 train_paths
#
# c:\users\luka\documents\phd\pathpy3\pathpy\algorithms\path_extraction.py in all_paths_from_temporal_network(tempnet, delta, max_subpath_length)
#     263     # generate a single time-unfolded DAG
#     264     LOG.info('Constructing time-unfolded DAG ...')
# --> 265     dag = DirectedAcyclicGraph.from_temporal_network(tempnet, delta)
#     266     node_map = { v.uid: v['original'].uid for v in dag.nodes }
#     267     LOG.info('finished.')
#
# c:\users\luka\documents\phd\pathpy3\pathpy\models\directed_acyclic_graph.py in from_temporal_network(cls, temporal_network, delta)
#     338                 #node_map[w_t] = edge.w.uid
#     339                 if v_t not in dag.nodes:
# --> 340                     dag.add_node(v_t, original=v)
#     341                 if w_t not in dag.nodes:
#     342                     dag.add_node(w_t, original=w)
#
# c:\users\luka\documents\phd\pathpy3\pathpy\models\network.py in add_node(self, *node, **kwargs)
#     691
#     692         """
# --> 693         self.nodes.add(*node, **kwargs)
#     694         self._add_node_properties()
#     695
#
# ~\anaconda3\envs\pathpy3dev\lib\site-packages\singledispatchmethod.py in _method(*args, **kwargs)
#      67         def _method(*args, **kwargs):
#      68             method = self.dispatcher.dispatch(args[0].__class__)
# ---> 69             return method.__get__(obj, cls)(*args, **kwargs)
#      70
#      71         _method.__isabstractmethod__ = self.__isabstractmethod__
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\node.py in _(self, *node, **kwargs)
#     278
#     279         # check if node with given uid str exists already
# --> 280         if _uid not in self:
#     281             # if not add new node with provided uid str
#     282             self[_uid] = self._node_class(uid=_uid, **kwargs)
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\collections.py in __contains__(self, item)
#      42         if item in self._map.values():
#      43             _contain = True
# ---> 44         elif isinstance(item, str) and item in self._map:
#      45             _contain = True
#      46         return _contain
#
# KeyboardInterrupt:

# %% [markdown]
# # PaCO: Path Counting in Temporal Networks
#
# We will look at two temporal netorks:

# %%
tn1 = pp.TemporalNetwork(directed=True)
tn1.add_edge("a", "b", timestamp=1)  # 0
tn1.add_edge("a", "b", timestamp=2)  # 1
tn1.add_edge("b", "a", timestamp=3)  # 2
tn1.add_edge("b", "c", timestamp=3)  # 3
tn1.add_edge("d", "c", timestamp=3)  # 4
tn1.add_edge("d", "c", timestamp=4)  # 5
tn1.add_edge("c", "d", timestamp=5)  # 6
tn1.add_edge("c", "b", timestamp=6)  # 7
tn1.add_edge("b", "c", timestamp=7)  # 8
tn1.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x52ab072ddbb94c0ebdbc14b7ded080a8"></div>
# <div id="x1d6516af35334db0a0413d9dcd25cb88"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": true, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": "1970-01-01T00:00:01", "end": "1970-01-01T00:00:08", "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "changes": [], "tedges": [{"uid": "0x2a18118a198", "startTime": 0, "endTime": 3, "active": true}, {"uid": "0x2a18118a198", "startTime": 3, "endTime": 5, "active": true}, {"uid": "0x2a18118a278", "startTime": 5, "endTime": 8, "active": true}, {"uid": "0x2a18118a4a8", "startTime": 5, "endTime": 8, "active": true}, {"uid": "0x2a18118a588", "startTime": 5, "endTime": 8, "active": true}, {"uid": "0x2a18118a588", "startTime": 8, "endTime": 11, "active": true}, {"uid": "0x2a18118a898", "startTime": 11, "endTime": 14, "active": true}, {"uid": "0x2a18118a710", "startTime": 14, "endTime": 16, "active": true}, {"uid": "0x2a18118a278", "startTime": 16, "endTime": 19, "active": true}], "tnodes": [], "links": [{"uid": "0x2a18118a198", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x2a18118a4a8", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "a", "directed": true, "curved": 0.5}, {"uid": "0x2a18118a278", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x2a18118a588", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x2a18118a898", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "d", "directed": true, "curved": 0.5}, {"uid": "0x2a18118a710", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "b", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }

# %%
tn2 = pp.TemporalNetwork(directed=True)
tn2.add_edge("a", "b", timestamp=1)  # 0
tn2.add_edge("a", "c", timestamp=2)  # 1
tn2.add_edge("b", "c", timestamp=2)  # 2
tn2.add_edge("c", "d", timestamp=3)  # 3
tn2.add_edge("b", "d", timestamp=4)  # 4
tn2.add_edge("d", "c", timestamp=4)  # 5
tn2.add_edge("d", "c", timestamp=5)  # 6
tn2.add_edge("d", "a", timestamp=5)  # 7
tn2.add_edge("c", "b", timestamp=6)  # 8
tn2.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x04d5ee35688e4103b4fa4e5c5ef72296"></div>
# <div id="xf733e9bdd5d24f2c8c653df85cddbba0"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": true, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": "1970-01-01T00:00:01", "end": "1970-01-01T00:00:07", "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "changes": [], "tedges": [{"uid": "0x2a18118ac18", "startTime": 0, "endTime": 3, "active": true}, {"uid": "0x2a18118ab70", "startTime": 3, "endTime": 6, "active": true}, {"uid": "0x2a18118ae10", "startTime": 3, "endTime": 6, "active": true}, {"uid": "0x2a18118f128", "startTime": 6, "endTime": 9, "active": true}, {"uid": "0x2a18118f208", "startTime": 9, "endTime": 13, "active": true}, {"uid": "0x2a18118f390", "startTime": 9, "endTime": 13, "active": true}, {"uid": "0x2a18118f390", "startTime": 13, "endTime": 16, "active": true}, {"uid": "0x2a18118f550", "startTime": 13, "endTime": 16, "active": true}, {"uid": "0x2a18118f470", "startTime": 16, "endTime": 19, "active": true}], "tnodes": [], "links": [{"uid": "0x2a18118ac18", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x2a18118ae10", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x2a18118ab70", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x2a18118f128", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "d", "directed": true, "curved": 0.5}, {"uid": "0x2a18118f208", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "d", "directed": true, "curved": 0.5}, {"uid": "0x2a18118f390", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x2a18118f550", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "a", "directed": true, "curved": 0.5}, {"uid": "0x2a18118f470", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "b", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is

# %% [markdown]
# For PaCo, we define paths in temporal networks to consist of temporal links which
# * can be continued topologically: the destination of a previous link is the same as the source of the next link, e.g. $(a,b,t_1)$ and $(b, e, t_2)$.
# * can be continued temporally: the timestamps of successive links $t_i$, $t_{i+1}$ satisfy
# $$t_i < t_{i+1}$$
# $$t_{i+1} - t_i \leq \delta $$
#
# For the first temporal network, and choices $\delta = 2$ and $\delta = 3$ the paths are as follows:

# %%
tn1_delta2= {
    1: {('a', 'b'): 2,
        ('b', 'a'): 1,
        ('b', 'c'): 2,
        ('c', 'b'): 1,
        ('c', 'd'): 1,
        ('d', 'c'): 2},
    2: {('a', 'b', 'a'): 2,
        ('a', 'b', 'c'): 2,
        ('b', 'c', 'd'): 1,
        ('c', 'b', 'c'): 1,
        ('d', 'c', 'b'): 1,
        ('d', 'c', 'd'): 2},
    3: {('a', 'b', 'c', 'd'): 2,
        ('d', 'c', 'b', 'c'): 1}
}

# %%
tn1_delta3 =  {
    1: {('a', 'b'): 2,
        ('b', 'a'): 1,
        ('b', 'c'): 2,
        ('c', 'b'): 1,
        ('c', 'd'): 1,
        ('d', 'c'): 2},
    2: {('a', 'b', 'a'): 2,
        ('a', 'b', 'c'): 2,
        ('b', 'c', 'b'): 1,
        ('b', 'c', 'd'): 1,
        ('c', 'b', 'c'): 1,
        ('d', 'c', 'b'): 2,
        ('d', 'c', 'd'): 2},
    3: {('a', 'b', 'c', 'b'): 2,
        ('a', 'b', 'c', 'd'): 2,
        ('b', 'c', 'b', 'c'): 1,
        ('d', 'c', 'b', 'c'): 2},
    4: {('a', 'b', 'c', 'b', 'c'): 2}
}

# %% [markdown]
# For the second temporal network and choices $\delta = 1$ and $\delta = 2$  the paths are following:

# %%
tn2_delta1 = {
    1: {('a', 'b'): 1,
        ('a', 'c'): 1,
        ('b', 'c'): 1,
        ('b', 'd'): 1,
        ('c', 'b'): 1,
        ('c', 'd'): 1,
        ('d', 'a'): 1,
        ('d', 'c'): 2},
    2: {('a', 'b', 'c'): 1,
        ('a', 'c', 'd'): 1,
        ('b', 'c', 'd'): 1,
        ('b', 'd', 'a'): 1,
        ('b', 'd', 'c'): 1,
        ('c', 'd', 'c'): 1,
        ('d', 'c', 'b'): 1},
    3: {('a', 'b', 'c', 'd'): 1,
        ('a', 'c', 'd', 'c'): 1,
        ('b', 'c', 'd', 'c'): 1,
        ('b', 'd', 'c', 'b'): 1},
    4: {('a', 'b', 'c', 'd', 'c'): 1}
}

# %%
tn2_delta2 = {
    1: {('a', 'b'): 1,
        ('a', 'c'): 1,
        ('b', 'c'): 1,
        ('b', 'd'): 1,
        ('c', 'b'): 1,
        ('c', 'd'): 1,
        ('d', 'a'): 1,
        ('d', 'c'): 2},
    2: {('a', 'b', 'c'): 1,
        ('a', 'c', 'd'): 1,
        ('b', 'c', 'd'): 1,
        ('c', 'd', 'c'): 2,
        ('b', 'd', 'c'): 1,
        ('c', 'd', 'a'): 1,
        ('b', 'd', 'a'): 1,
        ('d', 'c', 'b'): 2},
    3: {('a', 'b', 'c', 'd'): 1,
        ('a', 'c', 'd', 'c'): 2,
        ('b', 'c', 'd', 'c'): 2,
        ('b', 'd', 'c', 'b'): 1,
        ('a', 'c', 'd', 'a'): 1,
        ('b', 'c', 'd', 'a'): 1,
        ('c', 'd', 'c', 'b'): 2},
    4: {('a', 'b', 'c', 'd', 'a'): 1,
        ('a', 'c', 'd', 'c', 'b'): 2,
        ('b', 'c', 'd', 'c', 'b'): 2,
        ('a', 'b', 'c', 'd', 'c'): 2},
    5: {('a', 'b', 'c', 'd', 'c', 'b'): 2}
}

# %% [markdown]
# PaCo finds these paths, and outputs them in a `PathCollection`.

# %%
def test_PaCo():
    """
    Test the PaCo algorithm
    """
    for tn, delta, solution in [ (tn1, 3, tn1_delta3), (tn1, 3, tn1_delta3), (tn2, 1, tn2_delta1), (tn2, 2, tn2_delta2)]: 
        PaCo_paths = pp.algorithms.path_extraction.PaCo(tn, delta, skip_first=0, up_to_k=10)
        for l in solution:
            for path in solution[l]:
                assert PaCo_paths[path]["frequency"] == solution[l][path], f"Mismatch in counts for path {path}, correct counter is {solution[l][path]}, PaCo computed {PaCo_paths[path]['frequency']}."

                PaCo_paths.remove(path)
        assert len(PaCo_paths) == 0, f"PaCo found some non-existing paths."
    return True

# %%
test_PaCo()
# Out:
# True

# %%
paths = pp.algorithms.path_extraction.PaCo(train, 300, skip_first=0, up_to_k=10)

# %%
from collections import Counter
cnt = Counter()
for path in paths:
    p = tuple([v.uid for v in path.nodes])
    cnt[p] = paths[path]['frequency']

# %%
pp.io.infomap.to_state_file(cnt, 'test.state')

# %%
with io.open('test.state', 'r') as f:
    print(f.read())
# Out:
# *Vertices 111
# 1 "68"
# 2 "58"
# 3 "100"
# 4 "53"
# 5 "108"
# 6 "110"
# 7 "101"
# 8 "11"
# 9 "73"
# 10 "4"
# 11 "70"
# 12 "10"
# 13 "6"
# 14 "74"
# 15 "32"
# 16 "12"
# 17 "75"
# 18 "105"
# 19 "1"
# 20 "77"
# 21 "3"
# 22 "2"
# 23 "27"
# 24 "59"
# 25 "93"
# 26 "98"
# 27 "87"
# 28 "66"
# 29 "9"
# 30 "46"
# 31 "21"
# 32 "106"
# 33 "26"
# 34 "89"
# 35 "88"
# 36 "97"
# 37 "90"
# 38 "95"
# 39 "76"
# 40 "39"
# 41 "84"
# 42 "38"
# 43 "67"
# 44 "55"
# 45 "20"
# 46 "16"
# 47 "102"
# 48 "13"
# 49 "8"
# 50 "49"
# 51 "65"
# 52 "35"
# 53 "94"
# 54 "48"
# 55 "36"
# 56 "45"
# 57 "23"
# 58 "28"
# 59 "25"
# 60 "103"
# 61 "83"
# 62 "42"
# 63 "78"
# 64 "92"
# 65 "50"
# 66 "5"
# 67 "96"
# 68 "64"
# 69 "52"
# 70 "71"
# 71 "19"
# 72 "62"
# 73 "72"
# 74 "29"
# 75 "41"
# 76 "56"
# 77 "33"
# 78 "79"
# 79 "17"
# 80 "43"
# 81 "14"
# 82 "37"
# 83 "91"
# 84 "81"
# 85 "104"
# 86 "85"
# 87 "30"
# 88 "15"
# 89 "86"
# 90 "7"
# 91 "24"
# 92 "47"
# 93 "80"
# 2363 2 "{17}_58"
# 2364 25 "{20}_93"
# 2365 76 "{53}_56"
# 2366 58 "{25}_28"
# 2367 75 "{7}_41"
# 2368 75 "{25}_41"
# 2369 109 "{25-28}_63"
# 2370 109 "{28}_63"
# 2371 68 "{25-28}_64"
# 2372 68 "{28}_64"
# 2373 68 "{25-28-63}_64"
# 2374 68 "{28-63}_64"
# 2375 96 "{42-54}_57"
# 2376 65 "{42}_50"
# 2377 103 "{39}_54"
# 2378 111 "{2-4}_99"
# 2379 111 "{4}_99"
# 2380 93 "{24}_80"
# 2381 28 "{2-4}_66"
# 2382 93 "{52}_80"
# 2383 69 "{42-50}_52"
# 2384 93 "{42-50-52}_80"
# 2385 93 "{50-52}_80"
# 2386 109 "{42-54}_63"
# 2387 109 "{39-54}_63"
# 2388 109 "{54}_63"
# 2389 43 "{42}_67"
# 2390 7 "{2}_101"
# 2391 14 "{42-50-52}_74"
# 2392 14 "{50-52}_74"
# 2393 14 "{24-52}_74"
# 2394 14 "{52}_74"
# 2395 40 "{29}_39"
# 2396 83 "{eps}_91"
# 2397 64 "{91}_92"
# 2398 74 "{6}_29"
# 2399 83 "{29-39}_91"
# 2400 83 "{39}_91"
# 2401 40 "{6-29}_39"
# 2402 7 "{13}_101"
# 2403 96 "{56}_57"
# 2404 7 "{69}_101"
# 2405 52 "{1-12}_35"
# 2406 52 "{12}_35"
# 2407 52 "{25}_35"
# 2408 7 "{13-69}_101"
# 2409 16 "{10}_12"
# 2410 52 "{10-12}_35"
# 2411 109 "{1-12-35}_63"
# 2412 109 "{12-35}_63"
# 2413 109 "{25-35}_63"
# 2414 109 "{10-12-35}_63"
# 2415 96 "{43-45}_57"
# 2416 96 "{45}_57"
# 2417 83 "{29}_91"
# 2418 27 "{56}_87"
# 2419 37 "{16}_90"
# 2420 64 "{48}_92"
# 2421 54 "{29}_48"
# 2422 28 "{54}_66"
# 2423 47 "{65}_102"
# 2424 9 "{4}_73"
# 2425 2 "{1-12}_58"
# 2426 27 "{49}_87"
# 2427 61 "{65-74}_83"
# 2428 61 "{74}_83"
# 2429 86 "{65}_85"
# 2430 109 "{25}_63"
# ...
# 3827 3846
# 1029 3417
# 3417 3847
# 858 859
# 859 3830
# 3830 3848
# 2267 3831
# 3831 3849
# 3850 3851
# 231 3476
# 3476 3852
# 3853 3854
# 3394 3855
# 7 3856
# 7 11
# 11 3857
# 816 3858
# 2230 3859
# 7 3856
# 3856 3860
# 7 11
# 11 3857
# 3857 3861
# 3 472
# 472 3862
# 555 1434
# 1434 3863
# 816 3858
# 3858 3864
# 1 3865
# 179 2924
# 2924 3866
# 7 3856
# 3856 3867
# 7 11
# 11 3857
# 3857 3868
# 2100 3869
# 1 3832
# 3832 3870
# 238 2134
# 2134 3871
# 513 3872
# 7 3856
# 3856 3867
# 3867 3873
# 7 11
# 11 3857
# 3857 3868
# 3868 3874
# 3 472
# 472 494
# 494 3875
# 555 1434
# 1434 1442
# 1442 3876
# 179 3783
# 3783 3877
# 179 2924
# 2924 3866
# 3866 3878
# 384 1761
